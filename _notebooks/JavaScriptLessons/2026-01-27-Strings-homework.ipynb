# %% [markdown]
# ## Homework
#
# **Requirements:**
#
# - Include three strings of varying lengths
# - Find the length of each string and print them
# - Find the first and last character of each string and print them
# - Concatenate all three strings into a sentence and print the result

# %%
# %%js
#
# // Your code here:
#
# let string1 = "Weather: High - 86°F";
# let string2 = "wow,";
# let string3 = "California";
# let string4 = "is HOT today";
#
# console.log("Length of string1:", string1.length);
# console.log("Length of string2:", string2.length);
# console.log("Length of string3:", string3.length);
# console.log("Length of string4:", string4.length);
#
# console.log("First and last of string1:", string1[0], string1[string1.length - 1]);
# console.log("First and last of string2:", string2[0], string2[string2.length - 1]);
# console.log("First and last of string3:", string3[0], string3[string3.length - 1]);
# console.log("First and last of string4:", string4[0], string4[string4.length - 1]);
#
# let sentence = string1 + " " + string2 + " " + string3 + " " + string4 + ".";
# console.log("Concatenated sentence:", sentence);
